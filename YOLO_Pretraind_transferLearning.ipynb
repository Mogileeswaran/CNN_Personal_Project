# %%
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
print("A")
# Out:
# A

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 kB 23.2 MB/s eta 0:00:00
# ...

# %%
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 164MB/s]
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100% 476k/476k [00:00<00:00, 30.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 64.2ms
# Speed: 11.7ms preprocess, 64.2ms inference, 36.0ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict

# %%
#https://docs.ultralytics.com/modes/export/#usage-examples

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')  # load an official model
#model = YOLO('path/to/best.pt')  # load a custom model

# Predict with the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 86.2ms
# Speed: 4.0ms preprocess, 86.2ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
  # list of numpy arrays
results = model('https://ultralytics.com/images/bus.jpg')  # list of Results objects

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3023788ea52f> in <cell line: 2>()
#       1 # list of numpy arrays
# ----> 2 results = model('https://ultralytics.com/images/bus.jpg')  # list of Results objects
#       3
#       4 for result in results:
#       5   boxes = result.boxes  # Boxes object for bbox outputs
#
# NameError: name 'model' is not defined

# %%
results = model(source='https://vivrolfe.com/wp-content/uploads/2014/11/DS106_NewYorkGif.gif', stream=True)  # generator of Results objects
for r in results:
  boxes = r.boxes  # Boxes object for bbox outputs
  masks = r.masks  # Masks object for segment masks outputs
  probs = r.probs  # Class probabilities for classification outputs

# %%
results = model(source='https://vivrolfe.com/wp-content/uploads/2014/11/DS106_NewYorkGif2.gif', stream=True)
for r in results:
  boxes = r.boxes  # Boxes object for bbox outputs
  masks = r.masks  # Masks object for segment masks outputs
  probs = r.probs  # Class probabilities for classification outputs

# %%
res = model('https://raw.githubusercontent.com/ultralytics/yolov5/master/data/images/bus.jpg')
res_plotted = res[0].plot()
plt.imshow(res_plotted)
plt.show()

# %%
model.export(format='onnx')

# %%
cv2.imwrite("/content/sample_data/image.jpg", res_plotted)

# %%
from google.colab.patches import cv2_imshow

import cv2

import imageio

from ultralytics import YOLO

# Load the YOLOv8 model

model = YOLO('yolov8n.pt')







# Open the video file

video_path = "https://thumbs.gfycat.com/DimpledShrillDoe-mobile.mp4"
cap = cv2.VideoCapture(video_path)

# Create a list to hold the annotated frames
frames = []

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Add the annotated frame to the list of frames
        frames.append(annotated_frame)

        # Display the annotated frame
        cv2_imshow(annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# Save the annotated frames as a GIF
imageio.mimsave("/content/sample_data/object_detection_and_localization.gif", frames, fps=25)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
SAS_GenAI_Calbration = [
    {'ObjectDetection_Enabled', 'ObjectDetection_Disabled'},
    {'AutoCaptioningVoice_Enabled', 'AutoCaptioningVoice_Disabled'},
    {'Summarization_Enabled', 'Summarization_Disabled'}
]

# %%
print("HI")

# %%
import cv2
import imageio
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = "https://media.tenor.com/D8O_K8QgHUwAAAAC/walking-streets.gif"
cap = cv2.VideoCapture(video_path)

# Create a list to hold the annotated frames
frames = []

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Add the annotated frame to the list of frames
        frames.append(annotated_frame)

        # Display the annotated frame
        cv2_imshow(annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# Save the annotated frames as a GIF
imageio.mimsave("/content/sample_data/DS106_NewYorkGif__.gif", frames, fps=25)

# %%
#https://en.wikipedia.org/wiki/Harry_Potter_%28character%29#/media/File:Harry_Potter_character_poster.jpg

# %%
model = YOLO('yolov8n.pt')

res = model('https://upload.wikimedia.org/wikipedia/en/d/d7/Harry_Potter_character_poster.jpg',classes=None)
res_plotted = res[0].plot()
plt.imshow(res_plotted)
plt.show()

# %%
x = model.predict("https://images.herzindagi.info/image/2022/Mar/children-lord-shiva-main.jpg")

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %%
model.save("my_model.keras")

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/CNN_project/DataSets/pretrained/yolov3.h5')

# Show the model architecture
new_model.summary()
